# %%
import pandas as pd
print(pd.__version__)
print("test")
# Out:
# 3.0.1
# test

# %%
# Standard Libraries
import os
import json
import numpy as np
import pandas as pd
from tqdm import tqdm

# Image & Video Processing
import cv2
from PIL import Image

# Audio Processing
import librosa

# Machine Learning & Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report

# Deep Learning (PyTorch)
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, TensorDataset

# %%
from googleapiclient.discovery import build
import isodate
from langdetect import detect, DetectorFactory

# %%
# =========================
# FIX RANDOMNESS FOR LANGDETECT
# =========================
DetectorFactory.seed = 0

# %%
api_key = open(r"key.txt", 'r').read()
print(api_key)
# Out:
# AIzaSyDuvoovLVS3x5nQZZdb67UVizPQ8PbJx3Y

# %%
client_youtube = build("youtube", "v3", developerKey=api_key)

# %%
request = client_youtube.search().list(
    part="snippet",
    q="test",
    maxResults=1
)

response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'Ltjuq3M0EEjQPyQQRnagN2RaKxM', 'nextPageToken': 'CAEQAA', 'regionCode': 'IT', 'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 1}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'l5IJBuTakzyrrPJrFmgANEY40yY', 'id': {'kind': 'youtube#video', 'videoId': 'w3WV-14b-YY'}, 'snippet': {'publishedAt': '2026-04-21T22:01:10Z', 'channelId': 'UCS-hVm4JR8khVQShORDnqSA', 'title': 'TEST Loa Căng Đét, Nhạc Test Loa CỰC CHUẨN 8D - Nhạc Disco REMIX Bass Căng Cháy Khét➤Phê Hơn Sốt Rét', 'description': 'TEST Loa Căng Đét, Nhạc Test Loa CỰC CHUẨN 8D - Nhạc Disco REMIX Bass Căng Cháy Khét➤Phê Hơn Sốt Rét ➤ Thể Loại ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w3WV-14b-YY/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/w3WV-14b-YY/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/w3WV-14b-YY/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'KÊNH
# ...

# %%
BRANDS = {
    
    "Prime Creations": "UCsMHFdnMVXnDtiSl8II03XQ",
    "Chamberlain Coffee": "UCnczwH3BnO7hVYCo9tOUg7A",
    "JOYRIDE Sweets": "UCb3gn49M08LJgifWZ2urlNw",
    "wagamamauk": "UCLpPSkPtzCwRwy5zDVH7u1g",
    "Nando's UK": "UCVgYYZS_7RE-Hh9dFVMo8Rw",
    "GreggsOfficial": "UCGBwzp9B-zLX6VKFCdolQaQ",
    "Checkers and Rally's": "UC5ChdadDb5D8IwAH3eREx7Q",
    "BrainsBrewery": "UCF8ZwwpYSbunsV3_xAzdd1g",
    "Arnott's Biscuits": "UCCtBRzwWWpdKKJn0s31QPig",
    "Bakers Delight": "UCdLOLpIxS0hEz5SqVh4XzVQ",
    "Coca-Cola": "UCosXctaTYxN4YPIvI5Fpcrw",
    "Diet Coke": "UCZCOHRqaKeRVfKSwjEGAF5A",
    "7UP": "UCBeA22U5SiWlBOzmVmTB1LQ",
    "Canada Dry": "UC-Oe-4-IYVYI6xJwrB8-vQA",
    "DrinkSchweppes": "UCI-SWTG2z-lvbbUHqgylqWA",
    "Red Bull": "UCblfuW_4rakIf2h6aqANefA",
    "Gatorade": "UCKbGPPMiB37HbLIAKyV9bmQ",
    "evian": "UCzcYyo1s0WiFBzoCpQw4p_Q",
    "Twinings": "UC7gQmL7o4PgyNvqOQofpnzQ",
    "Costa Coffee": "UCAO1JItNCRih7COU0QCMSXQ",
    "IHOP": "UCtuRdhByiHTXmAu4ia4s47A",
    "Applebee's Grill & Bar": "UCmxJg6dHCSAB3UKH_bBd3rw",
    "Chili's Grill & Bar": "UCyMtENazjFr8cGjNrYrVsmA",
    "Outback Steakhouse": "UCjsR39UtmmEyYnc-F-JxPhg",
    "Olive Garden": "UCjK8erV4nrXp-1oy_7qoEMw",
    "Red Lobster": "UCLS452uNGZL0CkRiVpTnX0g",
    "Ghirardelli": "UCB6EwDvUn1wHT6PgAK6eWVA",
    "Cadbury Silk": "UCpgep5T-TP-M0LKK3jTOyVw",
    "Cadbury": "UCaopbQwxhv2POUZYPYngXlw",
    "Planters UK": "UCwrI8WOvf9Hyt9NGEMKFECQ",
    "Blue Diamond Almonds": "UChDuTA9fsmVn8NVJxl7UczA",
    "Rice Krispies": "UCS_O7HO0S0hl3RuHp1XIndw",
    "WeetabixFoodCo": "UCC3ceoNdeSFA9Wk2kAxge8Q",
    "Quaker Oats": "UCtff_aJSPlv-AbOdqPBepwA",
    "Knorr Noodles": "UCwTGuEBQFPpwrZYJQwUh2tQ",
    "Hellmanns": "UCi-h-thQ2WT-8gaTAjtlKUw",
    "ColdStoneCreameryHQ": "UCcRkMRsgYPyU16lgOfji00Q",
    "Ben's Original UK": "UCzbEf9x3WnWf8uB3d2p0WHg",
    "Carvel Ice Cream": "UC_vgUN8LizXub5WU4045OVA",
    "Nespresso": "UCdrsm2O-1i3zl5K0lVOEC2A",
    "Folgers": "UCIx0sm0wKK0cHLVp3a4EJcw",
    "Alani Nutrition":"UCshejrBjCKMuT6J1IevHwBg",
    "RYZE Superfoods":"UCQ88t8M8Gknpc8Oh6I9c-Ew",
    "MudWtr":"UCSsDLDLgR-BTLdjLv44SwLA",
    "Siggi's":"UCrjJsImfprUV96Rcb3xBAHg",
    "Boost Juice":"UC4q3uRdzU0XK3lD3vt9jHXA",
    "Bulla Dairy Foods":"UCd4dgJp-drTaJcGZ7qKLHGg",
    "Dick Smith Foods":"UCG11S5JtueJBMEEHFZRke9g",
    }

# %%
len(BRANDS)
# Out:
# 48

# %%
# 2. HELPER FUNCTIONS
def get_uploads_playlist_id(channel_id):
    try:
        res = client_youtube.channels().list(part="contentDetails", id=channel_id).execute()
        return res["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
    except:
        return None

def get_video_metadata(video_id_list):
    """Fetches stats and duration for a batch of videos"""
    res = client_youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=",".join(video_id_list)
    ).execute()

    batch_data = []
    for item in res.get("items", []):
        duration = isodate.parse_duration(item["contentDetails"]["duration"]).total_seconds()
        batch_data.append({
            "video_id": item["id"],
            "title": item["snippet"]["title"],
            "description": item["snippet"]["description"],
            "published_at": item["snippet"]["publishedAt"],
            "view_count": int(item["statistics"].get("viewCount", 0)),
            "comment_count": int(item["statistics"].get("commentCount", 0)),
            "duration_sec": duration
        })
    return batch_data

def is_english(text):
    try: return detect(text) == "en"
    except: return False

# %%
# 3. MAIN DATA COLLECTION LOOP
all_extracted_data = []

for brand, c_id in BRANDS.items():
    print(f"Processing: {brand}...")
    playlist_id = get_uploads_playlist_id(c_id)
    if not playlist_id: 
        print(f"For {brand} I was not able to find anything")
        continue
    else:
        print(f"I found something for {brand}")
    # Get video IDs from uploads
    v_ids = []
    req = client_youtube.playlistItems().list(part="snippet", playlistId=playlist_id, maxResults=50)
    res = req.execute()
    for item in res.get("items", []):
        v_ids.append(item["snippet"]["resourceId"]["videoId"])

    # Get full metadata
    metadata = get_video_metadata(v_ids)
    for video in metadata:
        video["brand"] = brand
        all_extracted_data.append(video)
# Out:
# Processing: Prime Creations...
# I found something for Prime Creations
# Processing: Chamberlain Coffee...
# I found something for Chamberlain Coffee
# Processing: JOYRIDE Sweets...
# I found something for JOYRIDE Sweets
# Processing: wagamamauk...
# I found something for wagamamauk
# Processing: Nando's UK...
# I found something for Nando's UK
# Processing: GreggsOfficial...
# I found something for GreggsOfficial
# Processing: Checkers and Rally's...
# I found something for Checkers and Rally's
# Processing: BrainsBrewery...
# I found something for BrainsBrewery
# Processing: Arnott's Biscuits...
# I found something for Arnott's Biscuits
# Processing: Bakers Delight...
# I found something for Bakers Delight
# Processing: Coca-Cola...
# I found something for Coca-Cola
# Processing: Diet Coke...
# I found something for Diet Coke
# Processing: 7UP...
# I found something for 7UP
# Processing: Canada Dry...
# I found something for Canada Dry
# Processing: DrinkSchweppes...
# ...

# %%
all_extracted_data
# Out:
# [{'video_id': 'FtQTdI3XXJk',
#   'title': 'PRIME Shake taste test! #drinkprime #prime #ksi #loganpaul #soccer #football #viral #shorts',
#   'description': '',
#   'published_at': '2026-04-21T14:53:11Z',
#   'view_count': 24866,
#   'comment_count': 35,
#   'duration_sec': 89.0,
#   'brand': 'Prime Creations'},
#  {'video_id': 'QEsQzkND8NE',
#   'title': "KSI's biggest test! #drinkprime #loganpaul #ksi #prime #primehydration #wwe #shorts #viral",
#   'description': '',
#   'published_at': '2026-04-15T20:48:47Z',
#   'view_count': 214139,
#   'comment_count': 52,
#   'duration_sec': 32.0,
#   'brand': 'Prime Creations'},
#  {'video_id': 'iSCKWZoLbCg',
#   'title': 'Logan Paul is in his PRIME! #drinkprime #prime #loganpaul #ksi #wwe #viral #shorts #primehydration',
#   'description': '',
#   'published_at': '2026-03-26T20:52:24Z',
#   'view_count': 36341,
#   'comment_count': 59,
#   'duration_sec': 55.0,
#   'brand': 'Prime Creations'},
#  {'video_id': 'JoGIg_DQSLs',
# ...

# %%
# 4. DATA CLEANING & FILTERING
if not all_extracted_data:
    print("Error: No data was extracted! Check your API key or Brand IDs.")
else:
    df = pd.DataFrame(all_extracted_data)
    
    # Check if the column actually exists before filtering
    if "duration_sec" in df.columns:
        # Filter 1: Duration
        df = df[(df["duration_sec"] >= 6) & (df["duration_sec"] <= 250)]
        
        # Filter 2: Engagement
        df = df[df["comment_count"] >= 7]
        
        # Filter 3: Keywords
        df["full_text"] = df["title"].fillna('') + " " + df["description"].fillna('')
        AD_KEYWORDS = ["ad", "commercial", "spot", "official", "campaign"]
        df = df[df["full_text"].str.lower().str.contains("|".join(AD_KEYWORDS))]
        
        print(f"Filtering complete. {len(df)} videos remain.")
    else:
        print("Error: DataFrame created but columns are missing. Check get_video_metadata function.")
# Out:
# Filtering complete. 142 videos remain.

# %%
# 4. DATA CLEANING & FILTERING
df.count()
# Out:
# video_id         142
# title            142
# description      142
# published_at     142
# view_count       142
# comment_count    142
# duration_sec     142
# brand            142
# full_text        142
# dtype: int64

# %%
df["url"] = "https://www.youtube.com/watch?v=" + df["video_id"]

df[["brand", "title", "url"]].head(20)
# Out:
#                   brand                                              title  \
# 39      Prime Creations  PRIME VS Gatorade Logan Paul #drinkprime #loga...
# 56   Chamberlain Coffee                   Honey Almond Cookie Matcha Latte
# 70   Chamberlain Coffee  emma chamberlain’s latest creation. visit cham...
# 83   Chamberlain Coffee                        the greatest roast on earth
# 86   Chamberlain Coffee                             meet coconut cold brew
# 91   Chamberlain Coffee                          emma & kendall's bloopers
# 92   Chamberlain Coffee                  emma & kendall's espresso martini
# 93   Chamberlain Coffee  emma and kendall’s unofficial history of the e...
# 99   Chamberlain Coffee            strangers taste test our new product...
# 180          wagamamauk        wok from halls episode #1 | hot katsu curry
# 194          wagamamauk  wok from home | the wagamama salad dressing | ...
# ...

# %%
print(f"Total videos selected: {len(df)}")
df.to_csv("videos_for_thesis_2dataset.csv", index=False)
# Out:
# Total videos selected: 142

# %%
PROJECT_PATH = "Thesis_Data"

# Create the main folder and subfolders locally
os.makedirs(os.path.join(PROJECT_PATH, "videos2"), exist_ok=True)
os.makedirs(os.path.join(PROJECT_PATH, "audio2"), exist_ok=True)
os.makedirs(os.path.join(PROJECT_PATH, "comments2"), exist_ok=True)

print(f"Project folders are ready at: {os.path.abspath(PROJECT_PATH)}")
# Out:
# Project folders are ready at: c:\Users\yasam\Desktop\thesis-notebooks\Thesis_Data

# %%
import subprocess

for index, row in df.iterrows():
    # print(index)
    video_id = row['video_id']
    video_url = f"https://www.youtube.com/watch?v={video_id}"

    print(f"--- Processing {index+1}/{len(df)}: {video_id} ---")

    # Define output file paths
    video_out = os.path.join(PROJECT_PATH, "videos2", f"{video_id}.mp4")
    audio_out = os.path.join(PROJECT_PATH, "audio2", f"{video_id}.wav")
    print(video_out)
    print(audio_out)
    # 2. Download Video 
    # Check if video already exists to skip redownloading
    # if not os.path.exists(video_out):
    print(f"Video output path: {video_out}")
    print(f"Downloading video...")
    try:
        cmd = [
            "yt-dlp",
            "-f", "bestvideo[ext=mp4][height<=480]+bestaudio[ext=m4a]/best[ext=mp4]/best",
            video_url,
            "-o", video_out
        ]
        subprocess.run(cmd, check=True)

    except subprocess.CalledProcessError as e:
        print(f"Error occurred while downloading video {video_id}: {e}")

    try:
        cmd2 = [
            "ffmpeg",
            "-i", video_out,
            "-ab", "160k",
            "-ac", "1",
            "-ar", "16000",
            "-vn", audio_out,
            "-y",
            "-loglevel", "quiet"
        ]
        subprocess.run(cmd2, check=True)
    except subprocess.CalledProcessError as e:
        print(f"Error occurred while extracting audio from video {video_id}: {e}")

print("\nTask Complete!")
# Out:
# --- Processing 40/142: AdF1JZjOssE ---
# Thesis_Data\videos2\AdF1JZjOssE.mp4
# Thesis_Data\audio2\AdF1JZjOssE.wav
# Video output path: Thesis_Data\videos2\AdF1JZjOssE.mp4
# ...
# --- Processing 57/142: gc1TrxFyA20 ---
# Thesis_Data\videos2\gc1TrxFyA20.mp4
# Thesis_Data\audio2\gc1TrxFyA20.wav
# Video output path: Thesis_Data\videos2\gc1TrxFyA20.mp4
# ...
# --- Processing 71/142: -kGLG4B3oiE ---
# Thesis_Data\videos2\-kGLG4B3oiE.mp4
# Thesis_Data\audio2\-kGLG4B3oiE.wav
# Video output path: Thesis_Data\videos2\-kGLG4B3oiE.mp4
# ...
# --- Processing 84/142: 5huTrJ5nm2U ---
# Thesis_Data\videos2\5huTrJ5nm2U.mp4
# Thesis_Data\audio2\5huTrJ5nm2U.wav
# Video output path: Thesis_Data\videos2\5huTrJ5nm2U.mp4
# ...
# --- Processing 87/142: J4fftbnA6-s ---
# Thesis_Data\videos2\J4fftbnA6-s.mp4
# Thesis_Data\audio2\J4fftbnA6-s.wav
# Video output path: Thesis_Data\videos2\J4fftbnA6-s.mp4
# ...
# --- Processing 92/142: K4z2PUSxti0 ---
# Thesis_Data\videos2\K4z2PUSxti0.mp4
# Thesis_Data\audio2\K4z2PUSxti0.wav
# ...

# %%
def get_video_comments(video_id, max_comments=100):
    comments = []
    try:
        request = client_youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            textFormat="plainText"
        )
        response = request.execute()

        for item in response.get("items", []):
            comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
            comments.append(comment)
    except Exception as e:
        print(f"Could not get comments for {video_id}: {e}")

    return comments

# Loop and save
for video_id in df['video_id']:
    video_comments = get_video_comments(video_id)
    with open(f"{PROJECT_PATH}/comments2/{video_id}.json", "w") as f:
        json.dump(video_comments, f)

# %%
# 1. Load Pre-trained ResNet50
# We use 'pretrained=True' to get the weights learned on ImageNet
resnet = models.resnet50(pretrained=True)
# Remove the last layer (the classifier) to get features instead of labels
resnet = torch.nn.Sequential(*(list(resnet.children())[:-1]))
resnet.eval() # Set to evaluation mode

# 2. Define Image Transformation
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

def extract_resnet_features(video_path):
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    if fps <= 0: fps = 30

    frame_features = []

    # Primary Loop: Extract 1 frame per second
    count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if count % int(fps) == 0:
            img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            pil_img = Image.fromarray(img)
            input_tensor = preprocess(pil_img).unsqueeze(0)

            with torch.no_grad():
                feature = resnet(input_tensor)
            frame_features.append(feature.flatten().numpy())
        count += 1

    # FALLBACK: If we didn't get any frames, grab the MIDDLE frame
    if not frame_features and total_frames > 0:
        middle_frame_idx = total_frames // 2
        cap.set(cv2.CAP_PROP_POS_FRAMES, middle_frame_idx)
        ret, frame = cap.read()
        if ret:
            img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            pil_img = Image.fromarray(img)
            input_tensor = preprocess(pil_img).unsqueeze(0)
            with torch.no_grad():
                feature = resnet(input_tensor)
            frame_features.append(feature.flatten().numpy())

    cap.release()

    if not frame_features:
        return np.zeros(2048) # Final safety net

    return np.mean(frame_features, axis=0)

# 3. Process all videos and save features
visual_features_dict = {}
video_files = [f for f in os.listdir(f"{PROJECT_PATH}/videos") if f.endswith('.mp4')]

print("Extracting ResNet features (Visual)...")
for v_file in tqdm(video_files):
    v_id = v_file.replace(".mp4", "")
    v_path = f"{PROJECT_PATH}/videos/{v_file}"

    try:
        features = extract_resnet_features(v_path)
        visual_features_dict[v_id] = features
    except Exception as e:
        print(f"Error processing {v_id}: {e}")

# Save the visual features to a file so you don't have to run this again
np.save(f"{PROJECT_PATH}/visual_features.npy", visual_features_dict)
print("Visual features saved!")
# Out:
# c:\Users\alberto.ferrante_kin\Desktop\thesis\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\alberto.ferrante_kin\Desktop\thesis\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to C:\Users\alberto.ferrante_kin/.cache\torch\hub\checkpoints\resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:02<00:00, 42.6MB/s]
# Extracting ResNet features (Visual)...
# 100%|██████████| 486/486 [30:35<00:00,  3.78s/it]
# ...

# %%
def extract_mfcc_features(audio_path):
    # Load audio file (16kHz was set in our ffmpeg step)
    y, sr = librosa.load(audio_path, sr=16000)

    # Extract MFCCs (typically 13 or 20 coefficients)
    # n_mfcc=20 is standard for sentiment/speech tasks
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)

    # Aggregate over time: take the mean and standard deviation
    # This captures both the average tone and the "energy" (variance)
    mfccs_mean = np.mean(mfccs, axis=1)
    mfccs_std = np.std(mfccs, axis=1)

    # Combine them into a 40-dimensional vector
    return np.hstack((mfccs_mean, mfccs_std))

# 3. Process all audio files
audio_features_dict = {}
audio_files = [f for f in os.listdir(f"{PROJECT_PATH}/audio") if f.endswith('.wav')]

print("Extracting MFCC features (Audio)...")
for a_file in tqdm(audio_files):
    v_id = a_file.replace(".wav", "")
    a_path = f"{PROJECT_PATH}/audio/{a_file}"

    try:
        features = extract_mfcc_features(a_path)
        audio_features_dict[v_id] = features
    except Exception as e:
        print(f"Error processing {v_id}: {e}")

# Save the audio features
np.save(f"{PROJECT_PATH}/audio_features.npy", audio_features_dict)
print("Audio features saved!")
# Out:
# Extracting MFCC features (Audio)...
# 100%|██████████| 486/486 [00:32<00:00, 15.03it/s]
# Audio features saved!

# %%
df.columns
# Out:
# Index(['video_id', 'title', 'description', 'published_at', 'view_count',
#        'comment_count', 'duration_sec', 'brand', 'full_text', 'url'],
#       dtype='str')

# %%
import google.generativeai as genai
import json
import os
import time
from tqdm import tqdm

# 1. SETUP GEMINI
# Replace with your actual key from https://aistudio.google.com/
GEMINI_API_KEY = "AIzaSyAaKruBg7_CbzWVqSOR-Hk5hfgw5Qee7Jo" 
genai.configure(api_key=GEMINI_API_KEY)

# Use 1.5 Flash for the best speed/cost balance
model = genai.GenerativeModel('gemini-1.5-flash',
                              generation_config={"response_mime_type": "application/json"})

# 2. PATHS
PROJECT_PATH = "Thesis_Data"
COMMENTS_DIR = os.path.join(PROJECT_PATH, "comments")
LABELS_DIR = os.path.join(PROJECT_PATH, "comment_labels")
os.makedirs(LABELS_DIR, exist_ok=True)

# 3. THE SYSTEM PROMPT (Telling the LLM it's Food & Beverage)
SYSTEM_PROMPT = """
You are an expert Brand Perception Analyst. I will provide a list of YouTube comments 
for a video advertisement in the 'Food and Beverage' category.

Your task:
1. Analyze the sentiment of each comment individually.
2. Classify each as: 'Positive', 'Negative', or 'Neutral'.
3. Account for food-specific nuances:
   - Sarcasm (e.g., 'Wow, another "healthy" soda' is likely Negative).
   - Emojis (e.g., 😋, 👏 are Positive; 🤢, 🤮 are Negative).
4. Provide a confidence score (0.0 to 1.0) for your classification.

Output the result strictly as a JSON array of objects:
[
  {"comment_index": 0, "sentiment": "Positive", "confidence": 0.95},
...
]
"""

def label_video_comments(video_id, comments):
    # Construct the message with the list of comments
    user_message = f"Here are the comments for Video ID {video_id}:\n"
    for i, cmd in enumerate(comments):
        user_message += f"[{i}] {cmd}\n"
    
    try:
        # Combining instructions and comments in one batch call
        response = model.generate_content(SYSTEM_PROMPT + "\n" + user_message)
        return json.loads(response.text)
    except Exception as e:
        print(f"Error processing {video_id}: {e}")
        return None

# 4. MAIN LOOP - USES YOUR LOCAL FILES
# Fix: This now correctly looks at your 'comments' folder
comment_files = os.listdir(COMMENTS_DIR)
print(f"Starting labeling for {len(comment_files)} videos...")

for file_name in tqdm(comment_files):
    video_id = file_name.replace('.json', '')
    output_path = os.path.join(LABELS_DIR, f"{video_id}_labeled.json")
    
    # Skip if already done
    if os.path.exists(output_path):
        continue
        
    # Load your existing local comments
    with open(os.path.join(COMMENTS_DIR, file_name), 'r') as f:
        comments = json.load(f)
        
    if not comments:
        continue

    # Process all comments for this video (Max 100) in one API call
    labeled_data = label_video_comments(video_id, comments)
    
    if labeled_data:
        with open(output_path, 'w') as f:
            json.dump(labeled_data, f)
            
    # Stay within Free Tier limits (15 Requests Per Minute)
    time.sleep(4)
# Out:
# Starting labeling for 551 videos...
#   0%|          | 0/551 [00:00<?, ?it/s]
# Error processing -24hAMItcAQ: 404 models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.
#   0%|          | 0/551 [00:04<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 84
#      81         json.dump(labeled_data, f)
#      83 # Stay within Free Tier limits (15 Requests Per Minute)
# ---> 84 time.sleep(4)
#
# KeyboardInterrupt:

# %%
from google import genai
from google.genai import types
import json
import os
import time
from tqdm import tqdm

# 1. SETUP GEMINI (Using the new 2026 Client)
GEMINI_API_KEY = "AIzaSyAaKruBg7_CbzWVqSOR-Hk5hfgw5Qee7Jo"
client = genai.Client(api_key=GEMINI_API_KEY)

# 2. PATHS
PROJECT_PATH = "Thesis_Data"
COMMENTS_DIR = os.path.join(PROJECT_PATH, "comments")
LABELS_DIR = os.path.join(PROJECT_PATH, "comment_labels")
os.makedirs(LABELS_DIR, exist_ok=True)

# 3. THE SYSTEM PROMPT
SYSTEM_PROMPT = """
You are an expert Brand Perception Analyst. I will provide a list of YouTube comments 
for a video advertisement in the 'Food and Beverage' category.

Your task:
1. Analyze the sentiment of each comment individually.
2. Classify as: 'Positive', 'Negative', or 'Neutral'.
3. Account for food-specific nuances (Sarcasm and Emojis).
4. Provide a confidence score (0.0 to 1.0).

Output strictly as a JSON array of objects:
[{"comment_index": 0, "sentiment": "Positive", "confidence": 0.95},...]
"""

def label_video_comments(video_id, comments):
    # Construct the user message
    user_message = f"Comments for Video ID {video_id}:\n"
    for i, c in enumerate(comments):
        user_message += f"[{i}] {c}\n"
    
    try:
        # Use 'gemini-2.0-flash' (stable) or 'gemini-3-flash-preview'
        response = client.models.generate_content(
            model="gemini-2.0-flash", 
            contents=user_message,
            config=types.GenerateContentConfig(
                system_instruction=SYSTEM_PROMPT,
                response_mime_type="application/json"
            )
        )
        return json.loads(response.text)
    except Exception as e:
        print(f"Error processing {video_id}: {e}")
        return None

# 4. FIXED MAIN LOOP: Iterate by UNIQUE Video ID
# This ensures we run only 489 times instead of 10,585
video_ids = df['video_id'].unique()
print(f"Starting labeling for {len(video_ids)} unique videos...")

for video_id in tqdm(video_ids):
    output_path = os.path.join(LABELS_DIR, f"{video_id}_labeled.json")
    comment_file = os.path.join(COMMENTS_DIR, f"{video_id}.json")
    
    # Skip if labeled already or if the comment file is missing
    if os.path.exists(output_path):
        continue
    if not os.path.exists(comment_file):
        # Optional: log missing files
        continue
        
    with open(comment_file, 'r') as f:
        comments = json.load(f)
        
    if not comments: 
        continue

    # Process all comments for this video in ONE API call
    labeled_data = label_video_comments(video_id, comments)
    
    if labeled_data:
        with open(output_path, 'w') as f:
            json.dump(labeled_data, f)
            
    # Free tier Rate Limit management (15 RPM)
    time.sleep(4)
# Out:
# Starting labeling for 10585 unique videos...
#   0%|          | 0/10585 [00:00<?, ?it/s]
# ...
